# %% [markdown]
# # Telco Customer Churn - EDA

# %% [markdown]
# # 📊 Telco Customer Churn Prediction
#
# Welcome to the machine learning project for predicting whether a telecom customer will churn or not. This notebook walks through the full ML pipeline:
#
# ---
#
# ## 📋 Table of Contents
#
# 1. [📌 Introduction](#introduction)
# 2. [📥 Data Loading](#data-loading)
# 3. [🔍 Exploratory Data Analysis (EDA)](#eda)
# 4. [🧹 Data Preprocessing](#data-preprocessing)
# 5. [📈 Model Training](#model-training)
# 6. [🧠 Predictions](#predictions)
# 7. [📊 Results and Evaluation](#results)
# 8. [💾 Save and Export](#save)
#
# ---
#
# ## 📌 Introduction <a id="introduction"></a>
#
# Goal: Predict whether a customer will leave the telecom service.
#
# ---
#
# ## 📥 Data Loading <a id="data-loading"></a>
#
# Load and inspect the Telco dataset.
#
# ---
#
# ## 🔍 Exploratory Data Analysis (EDA) <a id="eda"></a>
#
# Understand the distribution, correlations, and patterns in the dataset.
#
# ---
#
# ## 🧹 Data Preprocessing <a id="data-preprocessing"></a>
#
# Clean, encode, and prepare the dataset for model training.
#
# ---
#
# ## 📈 Model Training <a id="model-training"></a>
#
# Train ML models such as Logistic Regression, Decision Tree, or Random Forest.
#
# ---
#
# ## 🧠 Predictions <a id="predictions"></a>
#
# Make predictions using the trained model.
#
# ---
#
# ## 📊 Results and Evaluation <a id="results"></a>
#
# View prediction results with customer IDs and churn values.
#
# ---
#
# ## 💾 Save and Export <a id="save"></a>
#
# Export results and save the model for future use.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\AMIT\Telco Customer Churn\Telco Customer Churn\data\Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.countplot(x='Churn', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    if col != 'customerID':
        plt.figure(figsize=(6, 3))
        sns.countplot(data=df, x=col, hue='Churn')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

# %%
import sys
sys.path.append(r"D:\AMIT\Telco Customer Churn\Telco Customer Churn\src")

from train import train_model
train_model(r"D:\AMIT\Telco Customer Churn\Telco Customer Churn\data\Telco-Customer-Churn.csv")
# Out:
# 📊 Evaluation Metrics:
# Accuracy: 0.7925
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1033
#            1       0.64      0.49      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407
